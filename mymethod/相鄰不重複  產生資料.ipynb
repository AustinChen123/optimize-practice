# %%
import numpy as np
import pandas as pd

# %%
# 隨機產生一個值為 0~9 相鄰不重複的陣列
def data_generate(range_ = 9):
    import random
    arr = np.ones(1)
    long = random.randint(0, 10)
    for i in range(long):
        b = random.randint(0, range_)
        if (arr[len(arr)-1] == b):
            i-=1
            continue
        else:
            arr = np.append(arr,b)
    return arr

# %%
def data_merge(size = 10000, leng = 11):
    data = np.array([chr(i) for i in range(65,65 + leng -1)])
    count = 0
    path = np.array("←".join(data)).repeat(size)
    user = np.array("user#" + str(size)).repeat(size)
    for i in range(size):
        temp = np.round(data_generate()).astype(int)
        path[count] = np.array("←".join(data[temp]))
        count += 1 
    return path, user

# %%
# %timeit data_merge(100000)
# Out:
# 5.98 s ± 485 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
path, user = data_merge()
pd.DataFrame(path)
# Out:
#                         0
# 0         B←D←H←I←H←G←E←J
# 1           B←H←E←F←D←F←H
# 2                 B←G←J←H
# 3     B←G←J←E←F←H←B←E←J←D
# 4                 B←J←G←D
# 5               B←G←I←C←B
# 6       B←C←D←G←C←F←E←A←J
# 7                       B
# 8       B←G←A←H←F←C←H←D←I
# 9                 B←F←I←B
# 10              B←C←H←I←D
# 11                  B←E←H
# 12              B←E←A←H←I
# 13                  B←J←C
# 14                    B←I
# 15                    B←H
# 16                B←I←C←G
# 17                      B
# 18    B←F←H←D←H←A←I←G←I←E
# 19                B←F←I←A
# 20        B←H←I←C←G←A←B←I
# 21      B←J←I←A←I←H←E←D←A
# 22                      B
# 23              B←J←B←G←A
# 24            B←F←B←H←E←H
# 25                      B
# 26                B←C←A←C
# 27      B←F←E←G←I←H←E←H←C
# 28                    B←A
# 29                      B
# ...                   ...
# 9970  B←C←H←D←I←E←I←G←B←G
# 9971                  B←E
# 9972      B←G←A←F←G←B←D←I
# 9973  B←J←G←I←J←H←E←B←H←D
# 9974      B←C←B←H←D←E←H←B
# 9975          B←D←G←J←F←A
# 9976                B←J←E
# 9977                  B←C
# 9978          B←E←J←C←F←H
# 9979          B←I←H←B←G←B
# 9980            B←J←D←A←C
# 9981  B←D←F←A←F←G←B←E←J←I
# 9982                B←A←F
# 9983      B←H←G←B←I←J←B←G
# 9984          B←H←D←I←E←C
# 9985            B←A←E←C←D
# 9986                  B←E
# 9987          B←E←B←I←J←A
# 9988    B←A←E←G←J←D←J←B←D
# 9989          B←E←B←H←E←G
# 9990  B←J←F←G←D←A←C←J←C←E
# 9991          B←I←C←F←C←D
# 9992        B←H←G←I←H←B←A
# 9993        B←I←H←J←E←D←C
# 9994              B←C←D←G
# 9995    B←D←E←C←B←F←G←E←C
# 9996        B←I←J←G←I←C←A
# 9997        B←E←J←A←D←G←A
# 9998                B←I←B
# 9999                B←J←G
#
# [10000 rows x 1 columns]
